# %%
import numpy as np
import pandas as pd
import cPickle
import os

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

from time import time
from operator import itemgetter
from scipy.stats import randint as sp_randint

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, roc_curve, auc, precision_recall_curve
from sklearn.externals import joblib
from sklearn.grid_search import RandomizedSearchCV

from scipy.stats import sem

pd.set_option('display.mpl_style', 'default') 
pd.set_option('display.width', 5000) 
pd.set_option('display.max_columns', 60) 

# Font face used to match plots to blog.
font = {'family' : 'Droid Sans',
        'weight' : 'normal',
        'size': 10}

mpl.rc('font', **font)

# %%
def bootstrap_resample(X, n = None):
    """ Bootstrap resample an array_like
    Parameters
    ----------
    X : array_like
      data to resample
    n : int, optional
      length of resampled array, equal to len(X) if n==None
    Results
    -------
    returns X_resamples
    Source: http://nbviewer.ipython.org/gist/aflaxman/6871948
    """
    if n == None:
        n = len(X)
        
    resample_i = np.floor(np.random.rand(n)*len(X)).astype(int)
    X_resample = X[resample_i]
    return X_resample

# %%
def evaluate_model(model, features, target, test_features, test_target):
    print 'Training set score: ', model.score(features, target)
    print 'Test set score: ', model.score(test_features, test_target)
    preds = model.predict(test_features)
    print classification_report(np.array(test_target), preds)
    print 'Confusion matrix: '
    print pd.crosstab(test_target, preds, rownames=["Actual"], colnames=["Predicted"])

# %%
# %run ../load_pbp_data.py
# Loads the following dataframes:
# df        : training data from 2001-2012
# test_df   : testing data, 2013 until week 12
# games_df  : final scores, locations, and lines from 2000-2012

# %%
features = df[['qtr', 'sec_adj', 'sec_adj_sqrt', 'dwn', 'ytg', 'yfog', 'scorediff', 'sprv', 'ou']]
target = df['teamwin']

# %%
features.head()
# Out:
#    qtr  sec_adj  sec_adj_sqrt  dwn  ytg  yfog  scorediff  sprv    ou
# 0    1     3592      0.016683    1   10    24          0   9.5  33.5
# 1    1     3571      0.016732    2    6    28          0   9.5  33.5
# 2    1     3535      0.016817    1   10    36          0   9.5  33.5
# 3    1     3501      0.016898    2    4    42          0   9.5  33.5
# 4    1     3474      0.016964    1   10    62          0   9.5  33.5

# %%
test_features = test_df[['qtr', 'sec_adj', 'sec_adj_sqrt', 'dwn', 'ytg', 'yfog', 'scorediff', 'sprv', 'ou']]
test_target = test_df['teamwin']

# %%
def report(grid_scores, n_top=3):
    top_scores = sorted(grid_scores, key=itemgetter(1), reverse=True)[:n_top]
    for i, score in enumerate(top_scores):
        print("Model with rank: {0}".format(i + 1))
        print("Mean validation score: {0:.3f} (std: {1:.3f})".format(
              score.mean_validation_score,
              np.std(score.cv_validation_scores)))
        print("Parameters: {0}".format(score.parameters))
        print("")

# %%
test_df.describe()
# Out:
#                 qtr           min           sec          yfog           dwn           ytg     scorediff       teamwin       sec_adj  sec_adj_sqrt          sprv            ou
# count  16015.000000  16015.000000  16015.000000  16015.000000  16015.000000  16015.000000  16015.000000  16015.000000  16015.000000  16015.000000  16015.000000  16015.000000
# mean       2.547736     28.474243     28.534998     46.872682      2.011926      8.577833     -1.502279      0.497534   1736.989572      0.034837     -0.055136     45.063534
# std        1.114951     17.435902     17.706617     25.006895      1.012064      4.093365     10.842382      0.500010   1046.115938      0.036797      6.628594      4.688905
# min        1.000000      0.000000      0.000000      0.000000      1.000000      1.000000    -40.000000      0.000000      0.000000      0.016664    -26.500000     38.500000
# 25%        2.000000     13.000000     13.000000     25.000000      1.000000      6.000000     -7.000000      0.000000    839.000000      0.019499     -3.500000     41.500000
# 50%        3.000000     29.000000     28.000000     43.000000      2.000000     10.000000      0.000000      0.000000   1796.000000      0.023590     -1.000000     43.500000
# 75%        4.000000     43.000000     44.000000     66.000000      3.000000     10.000000      4.000000      1.000000   2629.000000      0.034503      3.500000     47.500000
# max        4.000000     60.000000     59.000000     99.000000      4.000000     40.000000     40.000000      1.000000   3600.000000      1.000000     26.500000     59.000000

# %%
df.describe()
# Out:
#                  gid            pid           dseq            len            qtr            min            sec           ptso           ptsd           timo           timd            dwn            ytg           yfog        sec_adj           sprv             ou        teamwin      scorediff   sec_adj_sqrt
# count  423382.000000  423382.000000  423382.000000  423382.000000  423382.000000  423382.000000  423382.000000  423382.000000  423382.000000  423382.000000  423382.000000  423382.000000  423382.000000  423382.000000  423382.000000  423382.000000  423382.000000  423382.000000  423382.000000  423382.000000
# mean     1855.613826  301489.893510       3.926046      25.143598       2.542385       6.704080      28.705004       9.772397      10.845239       2.528350       2.548427       2.009129       8.552579      48.402863    1742.803430      -0.159676      41.895050       0.511330      -1.072842       0.034971
# std       924.700148  150055.526669       3.050087      15.297450       1.116238       4.519903      17.715871       9.335284       9.879615       0.772197       0.743238       1.010768       4.081503      24.320703    1046.837083       6.382091       4.645987       0.499872      10.827652       0.037232
# min       260.000000   42247.000000       0.000000       0.000000       1.000000       0.000000       0.000000       0.000000       0.000000       0.000000       0.000000       1.000000       1.000000       1.000000       0.000000     -24.000000      30.500000       0.000000     -59.000000       0.016664
# 25%      1058.000000  172410.250000       2.000000       8.000000       2.000000       3.000000      13.000000       0.000000       3.000000       2.000000       2.000000       1.000000       6.000000      29.000000     842.000000      -4.500000      38.000000       0.000000      -7.000000       0.019485
# 50%      1861.000000  302524.500000       3.000000      30.000000       3.000000       7.000000      28.000000       7.000000       9.000000       3.000000       3.000000       2.000000      10.000000      45.000000    1800.000000      -1.000000      42.000000       1.000000       0.000000       0.023564
# 75%      2665.000000  431996.750000       6.000000      39.000000       4.000000      11.000000      44.000000      14.000000      17.000000       3.000000       3.000000       3.000000      10.000000      67.000000    2633.000000       4.000000      45.000000       1.000000       4.000000       0.034442
# max      3444.000000  560712.000000      24.000000      98.000000       4.000000      15.000000      59.000000      62.000000      62.000000       3.000000       3.000000       4.000000      50.000000      99.000000    3600.000000      24.000000      59.000000       1.000000      59.000000       1.000000

# %%
print df[['gid', 'pid', 'off', 'def', 'qtr', 'min', 'sec', 'sec_adj', 'scorediff', 'teamwin']].head(200).to_string()
# Out:
#      gid    pid  off  def  qtr  min  sec  sec_adj  scorediff  teamwin
# 0    260  42247  CHI  BAL    1   14   52     3592          0        0
# 1    260  42248  CHI  BAL    1   14   31     3571          0        0
# 2    260  42249  CHI  BAL    1   13   55     3535          0        0
# 3    260  42250  CHI  BAL    1   13   21     3501          0        0
# 4    260  42251  CHI  BAL    1   12   54     3474          0        0
# 5    260  42252  CHI  BAL    1   11   51     3411          0        0
# 6    260  42253  CHI  BAL    1   11   22     3382          0        0
# 7    260  42254  CHI  BAL    1   10   32     3332          0        0
# 8    260  42255  CHI  BAL    1    9   51     3291          0        0
# 9    260  42256  CHI  BAL    1    9   22     3262          0        0
# 10   260  42257  CHI  BAL    1    8   47     3227          0        0
# 11   260  42258  CHI  BAL    1    7   55     3175          0        0
# 12   260  42259  CHI  BAL    1    7   25     3145          0        0
# 13   260  42260  CHI  BAL    1    6   38     3098          0        0
# 14   260  42262  BAL  CHI    1    6   18     3078         -3        1
# 15   260  42263  BAL  CHI    1    6   11     3071         -3        1
# 16   260  42264  BAL  CHI    1    5   12     3012         -3        1
# 17   260  42265  BAL  CHI    1    4   55     2995         -3        1
# 18   260  42266  BAL  CHI    1    4   21     2961         -3        1
# 19   260  42267  BAL  CHI    1    3   47     2927         -3        1
# 20   260  42268  CHI  BAL    1    3   39     2919          3        0
# 21   260  42269  CHI  BAL    1    3   19     2899          3        0
# 22   260  42270  CHI  BAL    1    2   42     2862          3        0
# 23   260  42271  CHI  BAL    1    2   18     2838          3        0
# 24   260  42273  CHI  BAL    1    1   57     2817          3        0
# 25   260  42274  CHI  BAL    1    1   50     2810          3        0
# 26   260  42275  BAL  CHI    1    1   18     2778         -3        1
# 27   260  42276  BAL  CHI    1    0   56     2756         -3        1
# 28   260  42277  BAL  CHI    1    0   37     2737         -3        1
# 29   260  42278  BAL  CHI    2   15    0     2700         -3        1
# 30   260  42279  BAL  CHI    2   14   42     2682         -3        1
# 31   260  42280  BAL  CHI    2   14   18     2658         -3        1
# 32   260  42281  BAL  CHI    2   13   56     2636         -3        1
# 33   260  42282  CHI  BAL    2   13   35     2615          3        0
# 34   260  42284  CHI  BAL    2   13   28     2608          3        0
# 35   260  42285  CHI  BAL    2   13   22     2602          3        0
# 36   260  42286  CHI  BAL    2   13    6     2586          3        0
# 37   260  42287  CHI  BAL    2   12   25     2545          3        0
# 38   260  42288  CHI  BAL    2   12    1     2521          3        0
# 39   260  42289  CHI  BAL    2   11   39     2499          3        0
# 40   260  42290  CHI  BAL    2   11   10     2470          3        0
# 41   260  42291  CHI  BAL    2   10   49     2449          3        0
# 42   260  42293  CHI  BAL    2   10   18     2418          3        0
# 43   260  42294  CHI  BAL    2    9   57     2397          3        0
# 44   260  42295  CHI  BAL    2    9   29     2369          3        0
# 45   260  42298  CHI  BAL    2    8   15     2295          3        0
# 46   260  42299  CHI  BAL    2    7   51     2271          3        0
# 47   260  42300  CHI  BAL    2    7   45     2265          3        0
# 48   260  42301  CHI  BAL    2    7   40     2260          3        0
# 49   260  42302  BAL  CHI    2    7   38     2258         -3        1
# 50   260  42303  BAL  CHI    2    7   31     2251         -3        1
# 51   260  42305  BAL  CHI    2    6   30     2190         -3        1
# 52   260  42306  CHI  BAL    2    6    7     2167          3        0
# 53   260  42307  CHI  BAL    2    5   36     2136          3        0
# 54   260  42308  CHI  BAL    2    5   17     2117          3        0
# 55   260  42309  CHI  BAL    2    4   31     2071          3        0
# 56   260  42310  CHI  BAL    2    4   14     2054          3        0
# 57   260  42311  CHI  BAL    2    3   54     2034          3        0
# 58   260  42312  CHI  BAL    2    3   18     1998          3        0
# 59   260  42313  CHI  BAL    2    2   31     1951          3        0
# 60   260  42314  CHI  BAL    2    2    0     1920          3        0
# 61   260  42315  BAL  CHI    2    1   25     1885         -3        1
# 62   260  42316  BAL  CHI    2    1    6     1866         -3        1
# 63   260  42317  BAL  CHI    2    0   53     1853         -3        1
# 64   260  42318  BAL  CHI    2    0   45     1845         -3        1
# 65   260  42319  BAL  CHI    2    0   38     1838         -3        1
# 66   260  42320  BAL  CHI    2    0   29     1829         -3        1
# 67   260  42321  BAL  CHI    2    0   11     1811         -3        1
# 68   260  42322  BAL  CHI    2    0   11     1811         -3        1
# 69   260  42323  BAL  CHI    2    0    6     1806         -3        1
# 70   260  42324  BAL  CHI    2    0    2     1802         -3        1
# 71   260  42326  BAL  CHI    3   15    0     1800          0        1
# 72   260  42327  BAL  CHI    3   14   45     1785          0        1
# 73   260  42328  BAL  CHI    3   14   14     1754          0        1
# 74   260  42329  BAL  CHI    3   13   44     1724          0        1
# 75   260  42330  CHI  BAL    3   13   18     1698          0        0
# 76   260  42331  CHI  BAL    3   12   52     1672          0        0
# 77   260  42333  CHI  BAL    3   11   35     1595          0        0
# 78   260  42334  CHI  BAL    3   11   10     1570          0        0
# 79   260  42335  CHI  BAL    3   10   33     1533          0        0
# 80   260  42336  CHI  BAL    3    9   43     1483          0        0
# 81   260  42338  BAL  CHI    3    9   21     1461         -3        1
# 82   260  42339  BAL  CHI    3    8   55     1435         -3        1
# 83   260  42340  CHI  BAL    3    8   25     1405          3        0
# 84   260  42341  CHI  BAL    3    8   15     1395          3        0
# 85   260  42342  CHI  BAL    3    8   11     1391          3        0
# 86   260  42343  CHI  BAL    3    8    7     1387          3        0
# 87   260  42344  BAL  CHI    3    7   24     1344         -3        1
# 88   260  42345  BAL  CHI    3    7   15     1335         -3        1
# 89   260  42346  BAL  CHI    3    6   55     1315         -3        1
# 90   260  42347  BAL  CHI    3    6   18     1278         -3        1
# 91   260  42348  BAL  CHI    3    5   56     1256         -3        1
# 92   260  42349  BAL  CHI    3    5   31     1231         -3        1
# 93   260  42350  BAL  CHI    3    5    7     1207         -3        1
# 94   260  42351  BAL  CHI    3    4   26     1166         -3        1
# 95   260  42352  BAL  CHI    3    4    0     1140         -3        1
# 96   260  42353  BAL  CHI    3    3   23     1103         -3        1
# 97   260  42354  BAL  CHI    3    2   42     1062         -3        1
# 98   260  42355  BAL  CHI    3    2    3     1023         -3        1
# 99   260  42358  CHI  BAL    3    1   35      995         -4        0
# 100  260  42359  CHI  BAL    3    1   11      971         -4        0
# 101  260  42360  CHI  BAL    3    0   29      929         -4        0
# 102  260  42361  BAL  CHI    3    0   11      911          4        1
# 103  260  42362  BAL  CHI    3    0    4      904          4        1
# 104  260  42363  BAL  CHI    4   15    0      900          4        1
# 105  260  42364  BAL  CHI    4   14   52      892          4        1
# 106  260  42365  BAL  CHI    4   14   29      869          4        1
# 107  260  42366  BAL  CHI    4   13   57      837          4        1
# 108  260  42367  BAL  CHI    4   13   28      808          4        1
# 109  260  42368  BAL  CHI    4   13    3      783          4        1
# 110  260  42369  CHI  BAL    4   12   49      769         -4        0
# 111  260  42370  CHI  BAL    4   12   33      753         -4        0
# 112  260  42371  CHI  BAL    4   12    2      722         -4        0
# 113  260  42372  CHI  BAL    4   11    1      661         -4        0
# 114  260  42373  CHI  BAL    4   10   35      635         -4        0
# 115  260  42374  CHI  BAL    4   10    3      603         -4        0
# 116  260  42375  CHI  BAL    4    9   29      569         -4        0
# 117  260  42376  BAL  CHI    4    8   58      538          4        1
# 118  260  42377  BAL  CHI    4    8   46      526          4        1
# 119  260  42378  BAL  CHI    4    8   26      506          4        1
# 120  260  42379  BAL  CHI    4    7   55      475          4        1
# 121  260  42380  BAL  CHI    4    7   16      436          4        1
# 122  260  42381  CHI  BAL    4    6   55      415         -4        0
# 123  260  42382  CHI  BAL    4    6   30      390         -4        0
# 124  260  42383  CHI  BAL    4    5   47      347         -4        0
# 125  260  42384  BAL  CHI    4    5   24      324          4        1
# 126  260  42385  BAL  CHI    4    5    9      309          4        1
# 127  260  42386  BAL  CHI    4    4    1      241          4        1
# 128  260  42387  BAL  CHI    4    3   23      203          4        1
# 129  260  42388  BAL  CHI    4    2   57      177          4        1
# 130  260  42391  CHI  BAL    4    2   26      146        -11        0
# 131  260  42392  CHI  BAL    4    2    8      128        -11        0
# 132  260  42393  CHI  BAL    4    2    0      120        -11        0
# 133  260  42394  CHI  BAL    4    1   56      116        -11        0
# 134  260  42395  CHI  BAL    4    1   53      113        -11        0
# 135  260  42396  CHI  BAL    4    1   46      106        -11        0
# 136  260  42397  BAL  CHI    4    1   36       96         11        1
# 137  260  42398  BAL  CHI    4    1   34       94         11        1
# 138  260  42399  BAL  CHI    4    1   27       87         11        1
# 139  260  42401  BAL  CHI    4    0   37       37         11        1
# 140  261  42403  BUF  NO     1   14   51     3591          0        0
# 141  261  42404  BUF  NO     1   14   17     3557          0        0
# 142  261  42405  BUF  NO     1   13   43     3523          0        0
# 143  261  42406  NO   BUF    1   12   56     3476          0        1
# 144  261  42407  NO   BUF    1   12   41     3461          0        1
# 145  261  42408  NO   BUF    1   12    8     3428          0        1
# 146  261  42409  NO   BUF    1   11   28     3388          0        1
# 147  261  42410  BUF  NO     1   10   59     3359          0        0
# 148  261  42411  BUF  NO     1   10   47     3347          0        0
# 149  261  42412  BUF  NO     1   10   12     3312          0        0
# 150  261  42413  BUF  NO     1    9   33     3273          0        0
# 151  261  42414  BUF  NO     1    9    9     3249          0        0
# 152  261  42415  BUF  NO     1    8   34     3214          0        0
# 153  261  42416  BUF  NO     1    8   27     3207          0        0
# 154  261  42417  BUF  NO     1    7   46     3166          0        0
# 155  261  42418  NO   BUF    1    7   36     3156          0        1
# 156  261  42419  NO   BUF    1    6   54     3114          0        1
# 157  261  42420  NO   BUF    1    6   18     3078          0        1
# 158  261  42421  NO   BUF    1    5   37     3037          0        1
# 159  261  42422  BUF  NO     1    5   31     3031          0        0
# 160  261  42423  BUF  NO     1    4   57     2997          0        0
# 161  261  42424  BUF  NO     1    4   29     2969          0        0
# 162  261  42425  BUF  NO     1    3   50     2930          0        0
# 163  261  42426  BUF  NO     1    3    5     2885          0        0
# 164  261  42427  BUF  NO     1    2   18     2838          0        0
# 165  261  42428  BUF  NO     1    1   39     2799          0        0
# 166  261  42429  BUF  NO     1    1    8     2768          0        0
# 167  261  42430  BUF  NO     1    0   38     2738          0        0
# 168  261  42432  NO   BUF    1    0   19     2719         -3        1
# 169  261  42433  NO   BUF    2   15    0     2700         -3        1
# 170  261  42435  NO   BUF    2   14   54     2694         -3        1
# 171  261  42436  BUF  NO     2   14   48     2688          3        0
# 172  261  42437  BUF  NO     2   14   37     2677          3        0
# 173  261  42438  BUF  NO     2   13   58     2638          3        0
# 174  261  42439  BUF  NO     2   13   19     2599          3        0
# 175  261  42440  BUF  NO     2   12   32     2552          3        0
# 176  261  42441  BUF  NO     2   11   42     2502          3        0
# 177  261  42442  BUF  NO     2   11    5     2465          3        0
# 178  261  42443  BUF  NO     2   10   23     2423          3        0
# 179  261  42444  BUF  NO     2    9   42     2382          3        0
# 180  261  42445  BUF  NO     2    8   58     2338          3        0
# 181  261  42446  BUF  NO     2    8   43     2323          3        0
# 182  261  42447  BUF  NO     2    8   36     2316          3        0
# 183  261  42448  BUF  NO     2    8   31     2311          3        0
# 184  261  42450  NO   BUF    2    8   17     2297         -6        1
# 185  261  42451  NO   BUF    2    7   38     2258         -6        1
# 186  261  42452  NO   BUF    2    6   52     2212         -6        1
# 187  261  42453  BUF  NO     2    6   21     2181          6        0
# 188  261  42454  BUF  NO     2    6    8     2168          6        0
# 189  261  42455  BUF  NO     2    6    1     2161          6        0
# 190  261  42456  BUF  NO     2    5   21     2121          6        0
# 191  261  42458  BUF  NO     2    4   18     2058          6        0
# 192  261  42459  BUF  NO     2    3   35     2015          6        0
# 193  261  42460  NO   BUF    2    3    3     1983         -6        1
# 194  261  42461  NO   BUF    2    2   52     1972         -6        1
# 195  261  42462  NO   BUF    2    2   30     1950         -6        1
# 196  261  42463  NO   BUF    2    2   25     1945         -6        1
# 197  261  42464  BUF  NO     2    2   20     1940          6        0
# 198  261  42465  BUF  NO     2    2    6     1926          6        0
# 199  261  42466  BUF  NO     2    2    0     1920          6        0

# %%
test_df.head(15)
# Out:
#                      gid  qtr  min  sec  off  def  yfog  dwn  ytg  scorediff  teamwin  sec_adj  sec_adj_sqrt  sprv    ou
# 0   20130905_BAL@DEN        1   60    0  BAL  DEN    20    1   10          0        0     3600      0.016664   7.5  49.5
# 1   20130905_BAL@DEN        1   59   14  BAL  DEN    19    2   11          0        0     3554      0.016772   7.5  49.5
# 2   20130905_BAL@DEN        1   58   38  BAL  DEN    22    3    8          0        0     3518      0.016857   7.5  49.5
# 3   20130905_BAL@DEN        1   58   18  BAL  DEN    28    4    2          0        0     3498      0.016906   7.5  49.5
# 4   20130905_BAL@DEN        1   58   10  DEN  BAL    23    1   10          0        1     3490      0.016925  -7.5  49.5
# 5   20130905_BAL@DEN        1   58    5  DEN  BAL    23    2   10          0        1     3485      0.016937  -7.5  49.5
# 6   20130905_BAL@DEN        1   57   25  DEN  BAL    24    3    9          0        1     3445      0.017035  -7.5  49.5
# 7   20130905_BAL@DEN        1   57    4  DEN  BAL    34    1   10          0        1     3424      0.017087  -7.5  49.5
# 8   20130905_BAL@DEN        1   56   58  DEN  BAL    34    2   10          0        1     3418      0.017102  -7.5  49.5
# 9   20130905_BAL@DEN        1   56   24  DEN  BAL    41    3    3          0        1     3384      0.017188  -7.5  49.5
# 10  20130905_BAL@DEN        1   56   19  DEN  BAL    41    4    3          0        1     3379      0.017201  -7.5  49.5
# 11  20130905_BAL@DEN        1   56    9  BAL  DEN    20    1   10          0        0     3369      0.017226   7.5  49.5
# 12  20130905_BAL@DEN        1   55   35  BAL  DEN    34    1   10          0        0     3335      0.017314   7.5  49.5
# 13  20130905_BAL@DEN        1   55   31  BAL  DEN    34    2   10          0        0     3331      0.017324   7.5  49.5
# 14  20130905_BAL@DEN        1   55    3  BAL  DEN    38    3    6          0        0     3303      0.017397   7.5  49.5

# %%
param_dist = {"n_estimators": sp_randint(50, 200),
              "max_depth": [3, 4, 5],
              "max_features": sp_randint(1, 9),
              "min_samples_split": sp_randint(10, 100),
              "min_samples_leaf": sp_randint(10, 100),
              "bootstrap": [True, False],
              "criterion": ["gini", "entropy"]}

# %%
clf = RandomForestClassifier()

# %%
# WARNING: this will take several hours to run on a regular computer.
n_iter_search = 20
random_search = RandomizedSearchCV(clf, param_distributions=param_dist,
                                   n_iter=n_iter_search)
start = time()
random_search.fit(features, target)
print("RandomizedSearchCV took %.2f seconds for %d candidates"
      " parameter settings." % ((time() - start), n_iter_search))
report(random_search.grid_scores_)

# %%
# Use this simplified version if you just want to explore a classifier.
model_rf = RandomForestClassifier(oob_score = True, criterion = 'entropy', 
                                          max_features = 3, n_estimators = 30, min_samples_leaf = 50, 
                                          random_state = 1)

# %%
model_rf.fit(features, target)
# Out:
# RandomForestClassifier(bootstrap=True, compute_importances=None,
#             criterion='entropy', max_depth=None, max_features=3,
#             min_density=None, min_samples_leaf=50, min_samples_split=2,
#             n_estimators=30, n_jobs=1, oob_score=True, random_state=1,
#             verbose=0)

# %%
model_rf.score(features, target)
# Out:
# 0.81310022627320011

# %%
model_rf.score(test_features, test_target)
# Out:
# 0.64939119575398063

# %%
evaluate_model(model_rf, features, target, test_features, test_target)
# Out:
# Training set score:
# 0.813100226273
# Test set score:
# 0.649391195754
#              precision    recall  f1-score   support
#
#           0       0.65      0.65      0.65      8047
#           1       0.65      0.65      0.65      7968
#
# avg / total       0.65      0.65      0.65     16015
# Confusion matrix:
# Predicted     0     1
# Actual
# 0          5247  2800
# 1          2815  5153

# %%
full_probs = model_rf.predict_proba(test_features)

# Compute ROC curve and area the curve
fpr_full, tpr_full, thresholds_full = roc_curve(test_target, full_probs[:, 1])

# %%
roc_auc_full = auc(fpr_full, tpr_full)

print("Area under the full random forest ROC curve : %f" % roc_auc_full)
# Out:
# Area under the full random forest ROC curve : 0.707607

# %%
# %matplotlib qt
plt.figure(figsize=(16, 8))
plt.plot(fpr_full, tpr_full, label='Full random forest ROC curve (area = %0.2f)' % roc_auc_full)
# plt.plot(fpr_gbm, tpr_gbm, label='GBM ROC curve (area = %0.2f)' % roc_auc_gbm)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic curve')
plt.legend(loc="lower right")
plt.show()

# %%
train_performance_by_minute = pd.DataFrame(index = range(60), columns = ['rf_full'])
test_performance_by_minute = pd.DataFrame(index = range(60), columns = ['rf_full'])

# %%
seconds = 3600
index = 0

while seconds > 0:
    train_min_features = df[(df['sec_adj'] > seconds - 100) & (df['sec_adj'] <= seconds)][['qtr', 'sec_adj', 'sec_adj_sqrt', 'dwn', 'ytg', 'yfog', 'scorediff', 'sprv', 'ou']]
    test_min_features = test_df[(test_df['sec_adj'] > seconds - 100) & (test_df['sec_adj'] <= seconds)][['qtr', 'sec_adj', 'sec_adj_sqrt', 'dwn', 'ytg', 'yfog', 'scorediff', 'sprv', 'ou']]
    
    target_min = df[(df['sec_adj'] > seconds - 100) & (df['sec_adj'] <= seconds)]['teamwin']
    test_target_min = test_df[(test_df['sec_adj'] > seconds - 100) & (test_df['sec_adj'] <= seconds)]['teamwin']
    
    train_performance_by_minute.ix[index, 'rf_full'] = model_rf.score(train_min_features, target_min)
    test_performance_by_minute.ix[index, 'rf_full'] = model_rf.score(test_min_features, test_target_min)

    
    seconds -= 60
    index += 1

# %%
performance = pd.concat([train_performance_by_minute, test_performance_by_minute], axis = 1)
performance.columns = ['rf_full_train', 'rf_full_test']

# %%
# %matplotlib qt
plt.figure(figsize=(16, 8))
plt.plot(performance['rf_full_train'], label='RF (full) training')
plt.plot(performance['rf_full_test'], label='RF (full) test')
plt.xlim([0.0, 59.0])
plt.ylim([0.0, 1.0])
plt.ylabel('Accuracy')
plt.title('Accuracy of models by minutes elapsed')
plt.xlabel('Minutes elapsed')
plt.legend(loc="lower right")
plt.show()
